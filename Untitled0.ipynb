# %% [markdown]
# <a href="https://colab.research.google.com/github/Mijewljose/Mijewljose/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[2,8,9,0,4]
y=[10,2,7,3,6]
plt.plot(x,y,marker="o")
plt.title("Analysis")
plt.xlabel("Duration")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
a=["A","B","C","D"]
b=[2,9,5,6]
plt.bar(a,b)
plt.show()

# %%
plt.barh(a,b)
# Out:
# <BarContainer object of 4 artists>

# %%
y=[20,35,25,20]
x=["Apple","Grapes","Banana","Mango"]
plt.pie(y,labels=x)
plt.show()

# %%
x=[2,9,0,5,7,8]
y=[3,9,5,7,8,2]
plt.scatter(x,y)
plt.show()

# %%
x=[1,2,3,4,5]
y=[5,8,4,7,5]
#create figure
fig=plt.figure()
#adding axes on the figure
ax=fig.add_subplot(111)
#plotting data on the axes
ax.plot(x,y)
plt.show()

# %%
x=[1,2,3,4,5]
y=[50,40,40,80,20]
y2=[80,20,20,50,60]
plt.plot(x,y,'g', label="BMW", linewidth=5,linestyle="dashed")
plt.plot(x,y2, 'c', label="Ferrari", linewidth=5)

plt.title('car details in line plot')
plt.ylabel('Distance in Kms')
plt.xlabel('Days')

#text on ferrari line plot
plt.text(2.5,23,"Ferrari")
#text on bmw line port
plt.text(2.5, 43,"BMW")
plt.legend()

# %%
x=[1.5,2.6,3.5,4,9]
y=[3.25,6.3,4.23,1.35,3]
#plot graph
plt.plot(x,y,linestyle='dashed')
#display graph
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x=np.arange(0,math.pi*2,0.05)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
y4=np.tanh(x)
figure,axis=plt.subplots(2,2)
axis[0,0].plot(x,y1)
axis[0,0].set_title("Sine function")
axis[0,1].plot(x,y2)
axis[0,1].set_title("Cosine function")
axis[1,0].plot(x,y3)
axis[1,0].set_title("Tangent function")
axis[1,1].plot(x,y4)
axis[1,1].set_title("Tanh function")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [2, 4, 6, 8, 7, 5, 3]

plt.plot(x, y, marker='o', linestyle='dashed', color='red')
plt.xlabel('Range')
plt.ylabel('values')
plt.title(' a 7 point line plot')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(x, y, marker='o', color='red')
plt.xlabel('Range')
plt.ylabel('values')
plt.title('Scatter Plot')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
categories = [' A', ' B', 'C', 'D']
values = [10, 15, 7, 20]

plt.barh(categories, values, color='green', label='Horizontal Bar Chart')
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Horizontal Bar Chart')
plt.legend()
plt.show()

# %%
import numpy as np
data = np.random.randn(10000)

plt.hist(data, bins=30, color='green', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
import seaborn as sns

# %%
# #loading dataset (seaborn)
data = sns.load_dataset("iris")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data )
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#impoting packages

# %%
data =sns.load_dataset("iris")

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
plt.title('Title using matplotlib function')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load the tips dataset present by default in seaborn
tips=sns.load_dataset('tips')
sns.set_style('darkgrid')
#make a countplot
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>
